# %%
#example 1 
import matplotlib.pyplot as plt
import numpy as np
a = np.linspace(0,10,100)
b = np.exp(-a)
plt.plot(a,b)
plt.show()

# %%
#example 2
import matplotlib.pyplot as plt
from numpy.random import normal,rand
x = normal(size=200)
plt.hist(x,bins=30)
plt.show()

# %%
#example 3
import matplotlib.pyplot as plt
from numpy.random import rand
a = rand(100)
b = rand(100)
plt.scatter(a,b)
plt.show()

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm)
plt.show()

# %%
#教程中的例子
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-np.pi,np.pi,0.01)    #确定取值，步长
y = np.sin(x)                       #确定函数关系
plt.plot(x,y,'r')                   #画出图片               单引号中的字母是代表线条的颜色
plt.show()                          #显示图片

# %%
#example 2 
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-5,5,0.01)
y = x**3
plt.axis([-6,6,-10,10])
plt.plot(x,y)
plt.show()

# %%
x = np.arange(-5,5,0.01)
y = x**3
plt.xlim(-6,6)
plt.ylim(-500,500)            
plt.plot(x,y)
plt.show()

# %%
#example 3
x = np.arange(-5,5,0.01)
y = x**3
plt.axis([-6,6,-10,10])
plt.plot(x,y)
plt.grid(True)          #这行代码的作用就是显示网格
plt.show()

# %%
#example 4
x = np.linspace(-np.pi,np.pi,256,endpoint=True)
c = np.cos(x)
s = np.sin(x)
plt.plot(x,c,'c')    #括号里的先后顺序千万不能调转，因为先写的就是作为 横轴，然后接着就是 纵轴  ；调转了就会把图倒转了
plt.plot(x,s,'g')
plt.show()

# %%
#example 5 更改线宽
plt.plot(x,c,'c',linewidth=2.5)    
plt.plot(x,s,'m',linewidth=10)     #linewidth就是用来设置线宽的
plt.show()

# %%
#example 6 更改线条样式
x = np.linspace(-np.pi,np.pi,10,endpoint=True)
c = np.cos(x)
s = np.sin(x)
plt.plot(x,c,'c1')      #是在颜色设置项中，同时设置线条样式
plt.plot(x,s,'g+')      #是在颜色设置项中，同时设置线条样式
plt.show()

# %%
#还可以使用组合的线条样式
x = np.arange(-3,3,0.5,)
y = x+1
plt.plot(x,y,'rd:')   #这个就是使用组合的线条样式，⭐注意：组合线条样式不能够超过2个，假如超过2个就会报错。
plt.show()
